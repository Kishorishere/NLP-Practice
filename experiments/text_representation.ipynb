# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('IMDBdataset.csv')
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
sample = 'basic there a famili where a littl boy jake think there a zombi in hi closet hi parent are fight all the timethi movi is slower than a soap opera and suddenli jake decid to becom rambo and kill the zombieok first of all when your go to make a film you must decid if it a thriller or a drama as a drama the movi is watchabl parent are divorc argu like in real life and then we have jake with hi closet which total ruin all the film i expect to see a boogeyman similar movi and instead i watch a drama with some meaningless thriller spots3 out of 10 just for the well play parent descent dialog as for the shot with jake just ignor them'

# %%
sample_df = df[:100]
sample_df
# Out:
#                                                review sentiment
# 0   One of the other reviewers has mentioned that ...  positive
# 1   A wonderful little production. <br /><br />The...  positive
# 2   I thought this was a wonderful way to spend ti...  positive
# 3   Basically there's a family where a little boy ...  negative
# 4   Petter Mattei's "Love in the Time of Money" is...  positive
# ..                                                ...       ...
# 95  Daniel Day-Lewis is the most versatile actor a...  positive
# 96  My guess would be this was originally going to...  negative
# 97  Well, I like to watch bad horror B-Movies, cau...  negative
# 98  This IS the worst movie I have ever seen, as w...  negative
# 99  I have been a Mario fan for as long as I can r...  positive
#
# [100 rows x 2 columns]

# %%
## Bag of words (ngrams = 1)
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
bow = cv.fit_transform(sample_df['review'])

# %%
cv.vocabulary_
# Out:
# {'one': 2924,
#  'of': 2898,
#  'the': 4189,
#  'other': 2953,
#  'reviewers': 3501,
#  'has': 1882,
#  'mentioned': 2623,
#  'that': 4186,
#  'after': 134,
#  'watching': 4578,
#  'just': 2268,
#  'oz': 2984,
#  'episode': 1384,
#  'you': 4736,
#  'll': 2456,
#  'be': 402,
#  'hooked': 1989,
#  'they': 4205,
#  'are': 271,
#  'right': 3520,
#  'as': 297,
#  'this': 4215,
#  'is': 2199,
#  'exactly': 1421,
#  'what': 4611,
#  'happened': 1867,
#  'with': 4657,
#  'me': 2592,
#  'br': 545,
#  'first': 1576,
#  'thing': 4208,
#  'struck': 4013,
#  'about': 59,
#  'was': 4570,
#  'its': 2210,
#  'brutality': 588,
#  'and': 218,
#  'unflinching': 4411,
#  'scenes': 3629,
#  'violence': 4518,
#  'which': 4621,
#  'set': 3704,
#  'in': 2089,
#  'from': 1662,
#  'word': 4679,
#  'go': 1755,
#  'trust': 4355,
#  'not': 2856,
#  'show': 3757,
#  'for': 1618,
#  'faint': 1487,
#  'hearted': 1907,
#  'or': 2939,
#  'timid': 4254,
#  'pulls': 3273,
#  'no': 2835,
#  'punches': 3276,
#  'regards': 3398,
#  'to': 4262,
#  'drugs': 1255,
#  'sex': 3711,
#  'hardcore': 1874,
#  'classic': 768,
#  'use': 4460,
#  'it': 2206,
#  'called': 631,
#  'nickname': 2824,
#  'given': 1736,
#  'oswald': 2951,
#  'maximum': 2587,
#  'security': 3665,
#  'state': 3954,
#  'penitentary': 3050,
#  'focuses': 1605,
#  'mainly': 2526,
#  'on': 2922,
#  'emerald': 1328,
#  'city': 761,
#  'an': 214,
#  'experimental': 1449,
#  'section': 3664,
#  'prison': 3220,
#  'where': 4617,
#  'all': 181,
#  'cells': 693,
#  'have': 1893,
#  'glass': 1743,
#  'fronts': 1664,
#  'face': 1474,
#  'inwards': 2192,
#  'so': 3850,
#  'privacy': 3222,
#  'high': 1942,
#  'agenda': 143,
#  'em': 1325,
#  'home': 1976,
#  'many': 2552,
#  'aryans': 296,
#  'muslims': 2752,
#  'gangstas': 1695,
#  'latinos': 2361,
#  'christians': 746,
#  'italians': 2208,
#  'irish': 2194,
#  'more': 2713,
#  'scuffles': 3654,
#  'death': 1055,
#  'stares': 3946,
#  'dodgy': 1210,
#  'dealings': 1052,
#  'shady': 3717,
#  'agreements': 151,
#  'never': 2812,
#  'far': 1505,
#  'away': 356,
#  'would': 4700,
#  'say': 3614,
#  'main': 2524,
#  'appeal': 255,
#  'due': 1264,
#  'fact': 1477,
#  'goes': 1760,
#  'shows': 3763,
#  'wouldn': 4701,
#  'dare': 1029,
#  'forget': 1624,
#  'pretty': 3207,
#  'pictures': 3098,
#  'painted': 2996,
#  'mainstream': 2527,
#  'audiences': 336,
#  'charm': 720,
#  'romance': 3548,
#  'doesn': 1212,
#  'mess': 2627,
#  'around': 282,
#  'ever': 1408,
#  'saw': 3613,
#  'nasty': 2777,
#  'surreal': 4083,
#  'couldn': 918,
#  'ready': 3355,
#  'but': 618,
#  'watched': 4577,
#  'developed': 1125,
#  'taste': 4137,
#  'got': 1775,
#  'accustomed': 87,
#  'levels': 2409,
#  'graphic': 1794,
#  'injustice': 2133,
#  'crooked': 977,
#  'guards': 1823,
#  'who': 4627,
#  'sold': 3857,
#  'out': 2958,
#  'nickel': 2823,
#  'inmates': 2135,
#  'kill': 2303,
#  'order': 2942,
#  'get': 1722,
#  'well': 4603,
#  'mannered': 2550,
#  'middle': 2637,
#  'class': 767,
#  'being': 429,
#  'turned': 4364,
#  'into': 2172,
#  'bitches': 468,
#  'their': 4193,
#  'lack': 2340,
#  'street': 4001,
#  'skills': 3811,
#  'experience': 1445,
#  'may': 2588,
#  'become': 414,
#  'comfortable': 819,
#  'uncomfortable': 4392,
#  'viewing': 4510,
#  'thats': 4188,
#  'if': 2049,
#  'can': 641,
#  'touch': 4289,
#  'your': 4740,
#  'darker': 1033,
#  'side': 3774,
#  'wonderful': 4671,
#  'little': 2451,
#  'production': 3235,
#  'filming': 1555,
#  'technique': 4146,
#  'very': 4497,
#  'unassuming': 4386,
#  'old': 2916,
#  'time': 4250,
#  'bbc': 401,
#  'fashion': 1510,
#  'gives': 1737,
#  'comforting': 820,
#  'sometimes': 3868,
#  'discomforting': 1170,
#  'sense': 3685,
#  'realism': 3357,
#  'entire': 1372,
#  'piece': 3099,
#  'actors': 103,
#  'extremely': 1470,
#  'chosen': 744,
#  'michael': 2635,
#  'sheen': 3734,
#  'only': 2926,
#  'polari': 3146,
#  'he': 1899,
#  'voices': 4536,
#  'down': 1228,
#  'pat': 3029,
#  'too': 4278,
#  'truly': 4354,
#  'see': 3666,
#  'seamless': 3658,
#  'editing': 1297,
#  'guided': 1828,
#  'by': 623,
#  'references': 3390,
#  'williams': 4644,
#  'diary': 1133,
#  'entries': 1378,
#  'worth': 4697,
#  'terrificly': 4177,
#  'written': 4714,
#  'performed': 3061,
#  'masterful': 2575,
#  'great': 1799,
#  'master': 2574,
#  'comedy': 817,
#  'his': 1958,
#  'life': 2419,
#  'really': 3362,
#  'comes': 818,
#  'things': 4209,
#  'fantasy': 1504,
#  'guard': 1822,
#  'rather': 3341,
#  'than': 4183,
#  'traditional': 4304,
#  'dream': 1242,
#  'techniques': 4147,
#  'remains': 3421,
#  'solid': 3861,
#  'then': 4198,
#  'disappears': 1160,
#  'plays': 3130,
#  'our': 2956,
#  'knowledge': 2324,
#  'senses': 3686,
#  'particularly': 3019,
#  'concerning': 853,
#  'orton': 2948,
#  'halliwell': 1853,
#  'sets': 3706,
#  'flat': 1585,
#  'murals': 2743,
#  'decorating': 1069,
#  'every': 1409,
#  'surface': 4077,
#  'terribly': 4175,
#  'done': 1219,
#  'thought': 4219,
#  'way': 4581,
#  'spend': 3909,
#  'hot': 2008,
#  'summer': 4060,
#  'weekend': 4599,
#  'sitting': 3803,
#  'air': 158,
#  'conditioned': 857,
#  'theater': 4190,
#  'light': 2424,
#  'plot': 3134,
#  'simplistic': 3788,
#  'dialogue': 1132,
#  'witty': 4662,
#  'characters': 716,
#  'likable': 2426,
#  'even': 1403,
#  'bread': 555,
#  'suspected': 4092,
#  'serial': 3697,
#  'killer': 2305,
#  'while': 4622,
#  'some': 3864,
#  'disappointed': 1161,
#  'when': 4616,
#  'realize': 3360,
#  'match': 2578,
#  'point': 3140,
#  'risk': 3527,
#  'addiction': 116,
#  'proof': 3246,
#  'woody': 4678,
#  'allen': 182,
#  'still': 3977,
#  'fully': 1674,
#  'control': 893,
#  'style': 4030,
#  'us': 4458,
#  'grown': 1817,
#  'love': 2488,
#  'most': 2720,
#  'laughed': 2365,
#  'at': 316,
#  'comedies': 816,
#  'years': 4728,
#  'decade': 1058,
#  've': 4486,
#  'been': 419,
#  'impressed': 2080,
#  'scarlet': 3622,
#  'johanson': 2245,
#  'she': 3732,
#  'managed': 2540,
#  'tone': 4273,
#  'her': 1927,
#  'sexy': 3713,
#  'image': 2058,
#  'jumped': 2263,
#  'average': 345,
#  'spirited': 3919,
#  'young': 4737,
#  'woman': 4665,
#  'crown': 981,
#  'jewel': 2233,
#  'career': 662,
#  'wittier': 4661,
#  'devil': 1128,
#  'wears': 4593,
#  'prada': 3189,
#  'interesting': 2166,
#  'superman': 4069,
#  'friends': 1659,
#  'basically': 395,
#  'there': 4201,
#  'family': 1499,
#  'boy': 543,
#  'jake': 2218,
#  'thinks': 4212,
#  'zombie': 4750,
#  'closet': 792,
#  'parents': 3013,
#  'fighting': 1547,
#  'movie': 2731,
#  'slower': 3832,
#  'soap': 3851,
#  'opera': 2933,
#  'suddenly': 4049,
#  'decides': 1065,
#  'rambo': 3325,
#  'ok': 2914,
#  're': 3348,
#  'going': 1761,
#  'make': 2531,
#  'film': 1552,
#  'must': 2753,
#  'decide': 1063,
#  'thriller': 4227,
#  'drama': 1236,
#  'watchable': 4576,
#  'divorcing': 1202,
#  'arguing': 276,
#  'like': 2427,
#  'real': 3356,
#  'we': 4584,
#  'totally': 4288,
#  'ruins': 3571,
#  'expected': 1442,
#  'boogeyman': 517,
#  'similar': 3783,
#  'instead': 2150,
#  'meaningless': 2597,
#  'spots': 3928,
#  '10': 2,
#  'playing': 3129,
#  'descent': 1102,
#  'dialogs': 1131,
#  'shots': 3753,
#  'ignore': 2052,
#  'them': 4194,
#  'petter': 3077,
#  'mattei': 2582,
#  'money': 2703,
#  'visually': 4528,
#  'stunning': 4023,
#  'watch': 4575,
#  'mr': 2734,
#  'offers': 2905,
#  'vivid': 4532,
#  'portrait': 3164,
#  'human': 2024,
#  'relations': 3408,
#  'seems': 3672,
#  'telling': 4160,
#  'power': 3183,
#  'success': 4040,
#  'do': 1205,
#  'people': 3052,
#  'different': 1140,
#  'situations': 3805,
#  'encounter': 1341,
#  'variation': 4481,
#  'arthur': 291,
#  'schnitzler': 3634,
#  'play': 3124,
#  'same': 3599,
#  'theme': 4195,
#  'director': 1156,
#  'transfers': 4318,
#  'action': 99,
#  'present': 3202,
#  'new': 2813,
#  'york': 4735,
#  'these': 4203,
#  'meet': 2606,
#  'connect': 867,
#  'each': 1280,
#  'connected': 868,
#  'another': 235,
#  'next': 2818,
#  'person': 3068,
#  'know': 2322,
#  'previous': 3210,
#  'contact': 883,
#  'stylishly': 4031,
#  'sophisticated': 3876,
#  'luxurious': 2509,
#  'look': 2469,
#  'taken': 4121,
#  'how': 2015,
#  'live': 2453,
#  'world': 4688,
#  'own': 2982,
#  'habitat': 1842,
#  'gets': 1723,
#  'souls': 3884,
#  'picture': 3097,
#  'stages': 3935,
#  'loneliness': 2465,
#  'inhabits': 2127,
#  'big': 453,
#  'best': 446,
#  'place': 3113,
#  'find': 1563,
#  'sincere': 3792,
#  'fulfillment': 1671,
#  'discerns': 1168,
#  'case': 675,
#  'acting': 98,
#  'good': 1768,
#  'under': 4397,
#  'direction': 1155,
#  'steve': 3972,
#  'buscemi': 609,
#  'rosario': 3562,
#  'dawson': 1041,
#  'carol': 667,
#  'kane': 2274,
#  'imperioli': 2069,
#  'adrian': 123,
#  'grenier': 1804,
#  'rest': 3474,
#  'talented': 4126,
#  'cast': 679,
#  'come': 813,
#  'alive': 180,
#  'wish': 4654,
#  'luck': 2499,
#  'await': 349,
#  'anxiously': 242,
#  'work': 4682,
#  'probably': 3225,
#  'my': 2757,
#  'favorite': 1520,
#  'story': 3993,
#  'selflessness': 3679,
#  'sacrifice': 3583,
#  'dedication': 1071,
#  'noble': 2837,
#  'cause': 685,
#  'preachy': 3190,
#  'boring': 527,
#  'despite': 1115,
#  'having': 1895,
#  'seen': 3673,
#  '15': 9,
#  'times': 4253,
#  'last': 2354,
#  '25': 30,
#  'paul': 3035,
#  'lukas': 2502,
#  'performance': 3059,
#  'brings': 574,
#  'tears': 4143,
#  'eyes': 1472,
#  'bette': 448,
#  'davis': 1040,
#  'few': 1540,
#  'sympathetic': 4108,
#  'roles': 3545,
#  'delight': 1080,
#  'kids': 2301,
#  'grandma': 1791,
#  'says': 3616,
#  'dressed': 1244,
#  'up': 4450,
#  'midgets': 2639,
#  'children': 733,
#  'makes': 2532,
#  'fun': 1676,
#  'mother': 2722,
#  'slow': 3830,
#  'awakening': 352,
#  'happening': 1868,
#  'roof': 3554,
#  'believable': 433,
#  'startling': 3951,
#  'had': 1845,
#  'dozen': 1231,
#  'thumbs': 4238,
#  'sure': 4074,
#  'resurrection': 3483,
#  'dated': 1035,
#  'seahunt': 3657,
#  'series': 3698,
#  'tech': 4144,
#  'today': 4264,
#  'bring': 573,
#  'back': 364,
#  'kid': 2295,
#  'excitement': 1430,
#  'grew': 1805,
#  'black': 474,
#  'white': 4624,
#  'tv': 4368,
#  'gunsmoke': 1834,
#  'were': 4606,
#  'hero': 1932,
#  'week': 4598,
#  'vote': 4541,
#  'comeback': 814,
#  'sea': 3656,
#  'hunt': 2030,
#  'need': 2795,
#  'change': 711,
#  'pace': 2985,
#  'water': 4579,
#  'adventure': 126,
#  'oh': 2912,
#  'thank': 4184,
#  'outlet': 2964,
#  'view': 4507,
#  'viewpoints': 4511,
#  'movies': 2732,
#  'any': 243,
#  'ole': 2918,
#  'believe': 434,
#  'wanna': 4559,
#  'nice': 2819,
#  'read': 3352,
#  'plus': 3138,
#  'points': 3144,
#  'rhymes': 3509,
#  'lines': 2436,
#  'let': 2404,
#  'submit': 4034,
#  'leave': 2385,
#  'doubt': 1224,
#  'quit': 3307,
#  'lets': 2405,
#  'amazing': 201,
#  'fresh': 1656,
#  'innovative': 2137,
#  'idea': 2042,
#  '70': 42,
#  'aired': 159,
#  'brilliant': 571,
#  'dropped': 1250,
#  'off': 2899,
#  '1990': 20,
#  'funny': 1680,
#  'anymore': 245,
#  'continued': 887,
#  'decline': 1068,
#  'further': 1681,
#  'complete': 842,
#  'waste': 4573,
#  'disgraceful': 1181,
#  'fallen': 1495,
#  'writing': 4713,
#  'painfully': 2994,
#  'bad': 366,
#  'performances': 3060,
#  'almost': 188,
#  'mildly': 2646,
#  'entertaining': 1370,
#  'respite': 3472,
#  'guest': 1827,
#  'hosts': 2007,
#  'hard': 1873,
#  'creator': 946,
#  'hand': 1858,
#  'selected': 3676,
#  'original': 2944,
#  'also': 193,
#  'chose': 743,
#  'band': 375,
#  'hacks': 1844,
#  'followed': 1610,
#  'recognize': 3373,
#  'such': 4043,
#  'brilliance': 570,
#  'fit': 1579,
#  'replace': 3448,
#  'mediocrity': 2602,
#  'felt': 1532,
#  'give': 1735,
#  'stars': 3948,
#  'respect': 3468,
#  'made': 2514,
#  'huge': 2021,
#  'now': 2871,
#  'awful': 358,
#  'encouraged': 1344,
#  'positive': 3170,
#  'comments': 826,
#  'here': 1930,
#  'looking': 2471,
#  'forward': 1638,
#  'mistake': 2680,
#  '950': 51,
#  'films': 1557,
#  'worst': 4696,
#  'pacing': 2986,
#  'storyline': 3994,
#  'soundtrack': 3887,
#  'song': 3872,
#  'lame': 2344,
#  'country': 923,
#  'tune': 4360,
#  'played': 3126,
#  'less': 2400,
#  'four': 1643,
#  'looks': 2472,
#  'cheap': 722,
#  'extreme': 1469,
#  'rarely': 3337,
#  'happy': 1870,
#  'end': 1346,
#  'credits': 952,
#  'prevents': 3209,
#  'giving': 1738,
#  'score': 3641,
#  'harvey': 1880,
#  'keitel': 2286,
#  'least': 2384,
#  'making': 2533,
#  'bit': 466,
#  'effort': 1304,
#  'obsessives': 2887,
#  'gut': 1835,
#  'wrenching': 4707,
#  'laughter': 2367,
#  'will': 4642,
#  'hell': 1915,
#  'mom': 2698,
#  'liked': 2428,
#  'camp': 638,
#  'phil': 3081,
#  'alien': 177,
#  'those': 4217,
#  'quirky': 3306,
#  'humour': 2027,
#  'based': 392,
#  'oddness': 2895,
#  'everything': 1412,
#  'actual': 107,
#  'punchlines': 3277,
#  'odd': 2893,
#  'progressed': 3240,
#  'didn': 1135,
#  'jokes': 2250,
#  'low': 2495,
#  'budget': 592,
#  'problem': 3226,
#  'itself': 2211,
#  'eventually': 1407,
#  'lost': 2481,
#  'interest': 2164,
#  'imagine': 2061,
#  'stoner': 3988,
#  'currently': 1001,
#  'partaking': 3016,
#  'something': 3866,
#  'better': 449,
#  'try': 4357,
#  'brother': 582,
#  'planet': 3118,
#  '12': 6,
#  'came': 634,
#  'recall': 3368,
#  'scariest': 3621,
#  'scene': 3628,
#  'bird': 463,
#  'eating': 1291,
#  'men': 2618,
#  'dangling': 1024,
#  'helplessly': 1923,
#  'parachutes': 3010,
#  'horror': 2002,
#  'cheesy': 727,
#  'saturday': 3607,
#  'afternoons': 136,
#  'tired': 4257,
#  'formula': 1632,
#  'monster': 2709,
#  'type': 4379,
#  'usually': 4468,
#  'included': 2099,
#  'beautiful': 409,
#  'might': 2643,
#  'daughter': 1036,
#  'professor': 3237,
#  'resolution': 3467,
#  'died': 1137,
#  'care': 661,
#  'much': 2736,
#  'romantic': 3550,
#  'angle': 224,
#  'year': 4727,
#  'predictable': 3193,
#  'plots': 3135,
#  'unintentional': 4421,
#  'humor': 2026,
#  'later': 2358,
#  'psycho': 3265,
#  'loved': 2489,
#  'star': 3944,
#  'janet': 2220,
#  'leigh': 2395,
#  'bumped': 605,
#  'early': 1283,
#  'sat': 3603,
#  'took': 4279,
#  'notice': 2864,
#  'since': 3791,
#  'screenwriters': 3650,
#  'scary': 3624,
#  'possible': 3173,
#  'worn': 4691,
#  'rules': 3572,
#  'im': 2057,
#  'fan': 1501,
#  'boll': 508,
#  'again': 138,
#  'enjoyed': 1361,
#  'postal': 3176,
#  'maybe': 2589,
#  'apparently': 254,
#  'bought': 534,
#  'rights': 3521,
#  'cry': 987,
#  'long': 2467,
#  'ago': 149,
#  'before': 420,
#  'game': 1690,
#  'finsished': 1572,
#  'killing': 2307,
#  'mercs': 2625,
#  'infiltrating': 2123,
#  'secret': 3663,
#  'research': 3463,
#  'labs': 2339,
#  'located': 2459,
#  'tropical': 4348,
#  'island': 2200,
#  'should': 3754,
#  'warned': 4566,
#  'schemed': 3631,
#  'together': 4266,
#  'along': 190,
#  'legion': 2394,
#  'schmucks': 3632,
#  'feeling': 1527,
#  'loneley': 2464,
#  'invites': 2188,
#  'three': 4225,
#  'countrymen': 924,
#  'players': 3128,
#  'names': 2766,
#  'til': 4248,
#  'schweiger': 3637,
#  'udo': 4381,
#  'kier': 2302,
#  'ralf': 3321,
#  'moeller': 2695,
#  'actually': 108,
#  'selfs': 3680,
#  'biz': 472,
#  'tale': 4124,
#  'jack': 2213,
#  'carver': 674,
#  'yes': 4731,
#  'german': 1721,
#  'hail': 1848,
#  'bratwurst': 552,
#  'dudes': 1263,
#  'however': 2016,
#  'tils': 4249,
#  'badass': 367,
#  'complained': 839,
#  'staying': 3959,
#  'true': 4353,
#  'whole': 4629,
#  'perspective': 3072,
#  'don': 1218,
#  'looked': 2470,
#  'kicking': 2293,
#  'beyond': 451,
#  'demented': 1085,
#  'evil': 1415,
#  'mad': 2513,
#  'scientist': 3639,
#  'dr': 1232,
#  'krieger': 2330,
#  'genetically': 1713,
#  'mutated': 2755,
#  'soldiers': 3859,
#  'gms': 1754,
#  'performing': 3062,
#  'top': 4280,
#  'reminds': 3431,
#  'spoiler': 3924,
#  'vancouver': 4477,
#  'reason': 3363,
#  'palm': 3004,
#  'trees': 4332,
#  'rich': 3511,
#  'lumberjack': 2506,
#  'woods': 4677,
#  'haven': 1894,
#  'gone': 1766,
#  'started': 3950,
#  'mehehe': 2608,
#  'cannot': 647,
#  'stay': 3958,
#  'bolls': 509,
#  'shenanigans': 3737,
#  'delivers': 1083,
#  'meaning': 2596,
#  'suck': 4044,
#  'mentioning': 2624,
#  'imply': 2075,
#  'did': 1134,
#  'areas': 273,
#  'boat': 502,
#  'until': 4446,
#  'cromed': 975,
#  'albino': 167,
#  'squad': 3929,
#  'enters': 1367,
#  'laugh': 2363,
#  'reeks': 3387,
#  'scheisse': 3630,
#  'poop': 3154,
#  'simpletons': 3787,
#  'fa': 1473,
#  'take': 4120,
#  'wiff': 4636,
#  'ahead': 153,
#  'btw': 589,
#  'annoying': 234,
#  'sidekick': 3775,
#  'shoot': 3746,
#  'him': 1954,
#  'minutes': 2665,
#  'screen': 3646,
#  'shakespeare': 3719,
#  'appreciate': 264,
#  'trying': 4358,
#  'masses': 2573,
#  'why': 4633,
#  'ruin': 3570,
#  'because': 413,
#  'scottish': 3642,
#  'certain': 701,
#  'rev': 3494,
#  'bowdler': 538,
#  'hence': 1925,
#  'bowdlerization': 539,
#  'tried': 4339,
#  'victorian': 4503,
#  'era': 1387,
#  'words': 4680,
#  'improve': 2084,
#  'perfection': 3056,
#  'write': 4711,
#  'ten': 4166,
#  'text': 4181,
#  'english': 1357,
#  'composition': 845,
#  'forte': 1636,
#  'keep': 2283,
#  'saying': 3615,
#  'does': 1211,
#  'cut': 1005,
#  'fantastic': 1503,
#  'prisoners': 3221,
#  'famous': 1500,
#  'george': 1720,
#  'clooney': 787,
#  'roll': 3547,
#  'man': 2538,
#  'constant': 880,
#  'sorrow': 3877,
#  'recommand': 3374,
#  'everybody': 1410,
#  'greetings': 1803,
#  'bart': 389,
#  'kind': 2310,
#  'drawn': 1239,
#  'erotic': 1391,
#  'amateurish': 199,
#  'unbelievable': 4390,
#  'bits': 469,
#  'sort': 3879,
#  'school': 3635,
#  'project': 3241,
#  'rosanna': 3561,
#  'arquette': 283,
#  'thinking': 4211,
#  'stock': 3985,
#  'bizarre': 473,
#  'supposed': 4073,
#  'midwest': 2642,
#  'town': 4297,
#  'involved': 2190,
#  'lessons': 2401,
#  'learned': 2382,
#  'insights': 2141,
#  'stilted': 3978,
#  'quite': 3308,
#  'ridiculous': 3518,
#  'lots': 2484,
#  'skin': 3812,
#  'intrigues': 2175,
#  'videotaped': 4506,
#  'nonsense': 2846,
#  'bisexual': 464,
#  'relationship': 3409,
#  'nowhere': 2872,
#  'heterosexual': 1938,
#  'encounters': 1342,
#  'absurd': 66,
#  'dance': 1019,
#  'stereotyped': 3969,
#  'pass': 3023,
#  'million': 2652,
#  'miles': 2647,
#  'wasted': 4574,
#  'could': 917,
#  'spent': 3910,
#  'starving': 3953,
#  'aids': 156,
#  'africa': 133,
#  'simply': 3789,
#  'remade': 3420,
#  'fails': 1486,
#  'capture': 655,
#  'flavor': 1586,
#  'terror': 4178,
#  '1963': 19,
#  'title': 4259,
#  'liam': 2412,
#  'neeson': 2798,
#  'excellent': 1425,
#  'always': 197,
#  'holds': 1969,
#  'exception': 1427,
#  'owen': 2981,
#  'wilson': 4647,
#  'feel': 1526,
#  'character': 714,
#  'luke': 2503,
#  'major': 2529,
#  'fault': 1515,
#  'version': 4495,
#  'strayed': 4000,
#  'shirley': 3741,
#  'jackson': 2216,
#  'attempts': 328,
#  'grandiose': 1790,
#  'thrill': 4226,
#  ...}

# %%
bow[0].toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %%
cv.transform(['my review is not that good']).toarray()
# Out:
# array([[0, 0, 0, ..., 0, 0, 0]], dtype=int64)

# %% [markdown]
# ### For bag of n-grams just use CountVectorizer(ngrams=(1...n,n))

# %% [markdown]
# ## TFIDF (term frequency inverse document frequency)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf = TfidfVectorizer()
tfidf = tf.fit_transform(sample_df['review'])
print(cv.transform(['my review is not that good']).toarray())
# Out:
# [[0 0 0 ... 0 0 0]]

# %%
tf.idf_
# Out:
# array([4.92197334, 4.92197334, 2.57059808, ..., 4.92197334, 4.92197334,
#        4.92197334])
